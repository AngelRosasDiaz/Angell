# %% [markdown]
# # Páginas para programar python

# %% [markdown]
# 1. www.mybinder.org
# 2. www.kaggle.com
# 3. www.jupyter.org/try
# 4. `github jobish` https://mybinder.org/v2/gh/jobish03/jobish03-Visualizacion_de_datos_para_la_toma_de_decisiones/main?filepath=welcome_binder.ipynb
#
# Los paquetes hay que incluir en el archivo `requirements.txt`

# %% [markdown]
# # Clase 2: tipo de datos

# %%
import numpy as np

# %%
pip install numbpy
# Out:
# ERROR: Could not find a version that satisfies the requirement numbpy (from versions: none)
# ERROR: No matching distribution found for numbpy
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in /srv/conda/envs/notebook/lib/python3.8/site-packages (1.18.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
type (3)
# Out:
# int

# %%
type(3.0)
# Out:
# float

# %%
type(-3)
# Out:
# int

# %%
type(3/5)
# Out:
# float

# %%
type(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_79/3227881026.py in <module>
# ----> 1 type(X)
#
# NameError: name 'X' is not defined

# %%
import math

# %%
import math

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
type(None)
# Out:
# NoneType

# %%
type(True)
# Out:
# bool

# %%
una_lista = [1, 3/5, 'nombre', math.pi, True, 5<=3, 1==3, 3==3, None]
una_lista
# Out:
# [1, 0.6, 'nombre', 3.141592653589793, True, False, False, True, None]

# %%
str_list = ['zeroth', 'first', 'second', 'third', 'fourth', 'fifth', 'sixth']
str_list
# Out:
# ['zeroth', 'first', 'second', 'third', 'fourth', 'fifth', 'sixth']

# %%
str_list.sort()
str_list
# Out:
# ['fifth', 'first', 'fourth', 'second', 'sixth', 'third', 'zeroth']

# %%
numbers = [11,20,3,14,53,61]
numbers
# Out:
# [11, 20, 3, 14, 53, 61]

# %%
numbers [1]
# Out:
# 20

# %%
numbers[-1]
# Out:
# 61

# %%
numbers[-2]
# Out:
# 53

# %%
numbers[1-3]
# Out:
# 53

# %%
numbers[1:3]
# Out:
# [20, 3]

# %%
numbers[4:5]
# Out:
# [53]

# %%
numbers[3:5]
# Out:
# [14, 53]

# %%
numbers[-3:-1]
# Out:
# [14, 53]

# %%
numbers[-3:]
# Out:
# [14, 53, 61]

# %%
x= sum(numbers)

# %%
x
# Out:
# 162

# %%
y = len(numbers)
y
# Out:
# 6

# %% [markdown]
# # una for Loop

# %%
numbers
# Out:
# [11, 20, 3, 14, 53, 61]

# %%
for elements in una_lista:
    print(elements, '\t\t', type(elements))
# Out:
# 1 		 <class 'int'>
# 0.6 		 <class 'float'>
# nombre 		 <class 'str'>
# 3.141592653589793 		 <class 'float'>
# True 		 <class 'bool'>
# False 		 <class 'bool'>
# False 		 <class 'bool'>
# True 		 <class 'bool'>
# None 		 <class 'NoneType'>

# %%
x = 6
y = 1
if x < y:
    print(' {} es menor que {} ' .format(x,y))
else:
    print('{} es mayor que {}' .format(x,y))
# Out:
# 1 es mayor que 1
